# %% [markdown]
# Tasks 1: Data Cleaning and Preprocessing

# %% [markdown]
# Handle missing values in the dataset.

# %%
import pandas as pd 
df=pd.read_csv("Telco_Customer_Churn_Dataset .csv")
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %% [markdown]
# Convert categorical variables into numerical representations using techniques like one-hot encoding.

# %%
# finding categorical columns
df.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
categorical_columns=df.select_dtypes(include=['object']).columns

# %%
#printing categorical columns
categorical_columns
# Out:
# Index(['customerID', 'gender', 'Partner', 'Dependents', 'PhoneService',
#        'MultipleLines', 'InternetService', 'OnlineSecurity', 'OnlineBackup',
#        'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies',
#        'Contract', 'PaperlessBilling', 'PaymentMethod', 'TotalCharges',
#        'Churn'],
#       dtype='object')

# %%
#to know how many unique categories are there for every column
unique_count={}
for i in categorical_columns:
    unique_count[i]=df[i].nunique()
unique_count
# Out:
# {'customerID': 7043,
#  'gender': 2,
#  'Partner': 2,
#  'Dependents': 2,
#  'PhoneService': 2,
#  'MultipleLines': 3,
#  'InternetService': 3,
#  'OnlineSecurity': 3,
#  'OnlineBackup': 3,
#  'DeviceProtection': 3,
#  'TechSupport': 3,
#  'StreamingTV': 3,
#  'StreamingMovies': 3,
#  'Contract': 3,
#  'PaperlessBilling': 2,
#  'PaymentMethod': 4,
#  'TotalCharges': 6531,
#  'Churn': 2}

# %%
#consider only categorical columns whose unique values are less than 50
final_categorical_columns=[]
for col in unique_count:
    if unique_count[col] < 50 :
        final_categorical_columns.append(col)
final_categorical_columns
# Out:
# ['gender',
#  'Partner',
#  'Dependents',
#  'PhoneService',
#  'MultipleLines',
#  'InternetService',
#  'OnlineSecurity',
#  'OnlineBackup',
#  'DeviceProtection',
#  'TechSupport',
#  'StreamingTV',
#  'StreamingMovies',
#  'Contract',
#  'PaperlessBilling',
#  'PaymentMethod',
#  'Churn']

# %%
#converting categorical column to numerical using one-hot encoding 
df_encode=pd.get_dummies(df,columns=final_categorical_columns)
df_encode
# Out:
#       customerID  SeniorCitizen  tenure  MonthlyCharges TotalCharges  \
# 0     7590-VHVEG              0       1           29.85        29.85
# 1     5575-GNVDE              0      34           56.95       1889.5
# 2     3668-QPYBK              0       2           53.85       108.15
# 3     7795-CFOCW              0      45           42.30      1840.75
# 4     9237-HQITU              0       2           70.70       151.65
# ...          ...            ...     ...             ...          ...
# 7038  6840-RESVB              0      24           84.80       1990.5
# 7039  2234-XADUH              0      72          103.20       7362.9
# 7040  4801-JZAZL              0      11           29.60       346.45
# 7041  8361-LTMKD              1       4           74.40        306.6
# 7042  3186-AJIEK              0      66          105.65       6844.5
#
#       gender_Female  gender_Male  Partner_No  Partner_Yes  Dependents_No  ...  \
# ...

# %%
print("Before applying one-hot encoding column count : ",df.shape[1])
print("After applying one-hot encoding column count : ",df_encode.shape[1])
# Out:
# Before applying one-hot encoding column count :  21
# After applying one-hot encoding column count :  48

# %%
file_path = 'updated_dataset_after_task_1.csv'

# Save DataFrame to CSV
df_encode.to_csv(file_path, index=False)  # Set index=False to exclude row numbers from the CSV

print(f"DataFrame saved to '{file_path}'")
# Out:
# DataFrame saved to 'updated_dataset_after_task_1.csv'
